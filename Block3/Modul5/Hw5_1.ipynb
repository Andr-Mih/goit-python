# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %%
def square(arg):
    x,y = arg
    return 2*x+y

# %%
con= ({'type':'eq', 'fun': lambda x: x[0]*x[1]-1000})

# %%
minimize(square, [5,5], constraints= con)
# Out:
#      fun: 89.4427190997243
#      jac: array([2., 1.])
#  message: 'Optimization terminated successfully.'
#     nfev: 67
#      nit: 15
#     njev: 15
#   status: 0
#  success: True
#        x: array([22.36067646, 44.72136617])
