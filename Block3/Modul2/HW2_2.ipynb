# %%
import pandas as pd
import numpy as np

# %%
url = 'https://docs.google.com/spreadsheets/d/1jOjukFoW306uv53FY6R79NcwQy5S4TZ9nprzRmBSHOs/export?format=csv&gid=271672803'
temp = pd.read_csv(url)

# %%
temp.head(3)
# Out:
#    N           Должность Язык.программирования  ... salary Валюта  cls
# 0  1  Junior QA engineer                   NaN  ...    400    NaN   QA
# 1  2  Junior QA engineer                   NaN  ...    430    NaN   QA
# 2  3   Software Engineer               C#/.NET  ...   2500    NaN  DEV
#
# [3 rows x 25 columns]

# %%
temp.shape
# Out:
# (8704, 25)

# %%
temp.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
temp.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %%
temp.drop(['cls', 'Валюта', 'Предметная.область', 'Университет', 'Специализация'], axis=1, inplace= True)

# %%
temp.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %%
tmp = pd.read_csv(url)
tmp.dropna(inplace=True)
tmp
# Out:
# Empty DataFrame
# Columns: [N, Должность, Язык.программирования, Специализация, Общий.опыт.работы, Опыт.работы.на.текущем.месте, Зарплата.в.месяц, Изменение.зарплаты.за.12.месяцев, Город, Размер.компании, Тип.компании, Пол, Возраст, Образование, Университет, Еще.студент, Уровень.английского, Предметная.область, Дата.заполнения, User.Agent, exp, current_job_exp, salary, Валюта, cls]
# Index: []

# %%
python_data = temp[temp['Язык.программирования'] == 'Python']
python_data
# Out:
#          N                 Должность Язык.программирования  ... salary Валюта  cls
# 12      13         Software Engineer                Python  ...    800    NaN  DEV
# 68      69         Software Engineer                Python  ...    900    NaN  DEV
# 87      88  Junior Software Engineer                Python  ...    600    NaN  DEV
# 114    115  Junior Software Engineer                Python  ...    685    NaN  DEV
# 143    144  Junior Software Engineer                Python  ...    750    NaN  DEV
# ...    ...                       ...                   ...  ...    ...    ...  ...
# 8546  8547         Software Engineer                Python  ...   2000    NaN  DEV
# 8625  8626         Software Engineer                Python  ...   1750    NaN  DEV
# 8635  8636  Senior Software Engineer                Python  ...   4000    NaN  DEV
# 8673  8674  Junior Software Engineer                Python  ...    350    NaN  DEV
# ...

# %%
python_data.shape
# Out:
# (207, 25)

# %%
python_data.groupby('Должность').mean()
# Out:
#                                     N  ...       salary
# Должность                              ...
# Junior Software Engineer  3559.063492  ...   560.841270
# Senior Software Engineer  4781.870968  ...  3387.096774
# Software Engineer         3668.840000  ...  1799.070000
# System Architect          6989.000000  ...  4000.000000
# Technical Lead            5370.181818  ...  3165.909091
#
# [5 rows x 8 columns]

# %%
new_set = python_data.groupby('Должность')
salary_set = new_set.agg({'Зарплата.в.месяц': ['max', 'min', 'mean']})
salary_set
# Out:
#                          Зарплата.в.месяц
#                                       max   min         mean
# Должность
# Junior Software Engineer             1250   100   560.841270
# Senior Software Engineer             9200  1300  3387.096774
# Software Engineer                    5400   500  1799.070000
# System Architect                     5000  3000  4000.000000
# Technical Lead                       6200  1425  3165.909091

# %%
salary_set['Зарплата.в.месяц']['min']
# Out:
# Должность
# Junior Software Engineer     100
# Senior Software Engineer    1300
# Software Engineer            500
# System Architect            3000
# Technical Lead              1425
# Name: min, dtype: int64

# %%
def fill_avg_salary(data):
  return (data['Зарплата.в.месяц']['min'] + data['Зарплата.в.месяц']['max'])/2

# %%
salary_set['avg'] = salary_set.apply(lambda x: fill_avg_salary(x), axis = 1)
salary_set
# Out:
#                          Зарплата.в.месяц                        avg
#                                       max   min         mean
# Должность
# Junior Software Engineer             1250   100   560.841270   675.0
# Senior Software Engineer             9200  1300  3387.096774  5250.0
# Software Engineer                    5400   500  1799.070000  2950.0
# System Architect                     5000  3000  4000.000000  4000.0
# Technical Lead                       6200  1425  3165.909091  3812.5

# %%
python_data.describe()
# Out:
#                  N  Зарплата.в.месяц  ...  current_job_exp       salary
# count   207.000000        207.000000  ...       207.000000   207.000000
# mean   3924.603865       1753.937198  ...         1.128019  1753.937198
# std    2465.482835       1314.751537  ...         1.334489  1314.751537
# min      13.000000        100.000000  ...         0.000000   100.000000
# 25%    1946.500000        750.000000  ...         0.250000   750.000000
# 50%    3680.000000       1425.000000  ...         1.000000  1425.000000
# 75%    5805.000000       2500.000000  ...         1.500000  2500.000000
# max    8696.000000       9200.000000  ...        10.000000  9200.000000
#
# [8 rows x 7 columns]

# %%
python_data.to_csv('file.csv')
