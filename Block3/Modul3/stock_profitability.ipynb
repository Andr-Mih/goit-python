# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({'A': [25,-10, 10, 5, 35, 13], 'B': [0, 15, -5, 5, 20, 25], 'C': [10, 25, -15, -5, -5, 15]})

# %%
fig, ax = plt.subplots()
ax = sns.regplot(x = 'A', y = 'B', data=data)

# %%
ax = sns.regplot(x = 'A', y = 'C', data=data)

# %%
data
# Out:
#     A   B   C
# 0  25   0  10
# 1 -10  15  25
# 2  10  -5 -15
# 3   5   5  -5
# 4  35  20  -5
# 5  13  25  15

# %%
ax = sns.regplot(x = 'B', y = 'C', data=data)

# %%
sns.pairplot(data)

# %%
data[['A', 'B', 'C']].corr()
# Out:
#           A         B         C
# A  1.000000  0.075439 -0.408807
# B  0.075439  1.000000  0.508034
# C -0.408807  0.508034  1.000000

# %% [markdown]
# Исходя из матрицы корелляции и графиков регрессии наименее зависимы друг от друга доходности акций А и В.
